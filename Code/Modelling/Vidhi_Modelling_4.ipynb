# %%
# !pip install snowflake-snowpark-python
# !pip install snowflake-ml-python
#pip install googletrans
# Out:
# Requirement already satisfied: snowflake-snowpark-python in /usr/local/lib/python3.10/dist-packages (1.15.0)
# Requirement already satisfied: setuptools>=40.6.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-snowpark-python) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from snowflake-snowpark-python) (0.43.0)
# Requirement already satisfied: snowflake-connector-python<4.0.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-snowpark-python) (3.10.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-snowpark-python) (4.11.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from snowflake-snowpark-python) (6.0.1)
# Requirement already satisfied: cloudpickle!=2.1.0,!=2.2.0,<=2.2.1,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-snowpark-python) (2.2.1)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (1.16.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (42.0.5)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (24.1.0)
# Requirement already satisfied: pyjwt<3.0.0 in /usr/lib/python3/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (2.3.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (2023.4)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (2.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (2024.2.2)
# Requirement already satisfied: filelock<4,>=3.5 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (3.14.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (4.2.1)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (0.12.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (2.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->snowflake-connector-python<4.0.0,>=3.6.0->snowflake-snowpark-python) (1.26.18)
# Requirement already satisfied: snowflake-ml-python in /usr/local/lib/python3.10/dist-packages (1.5.0)
# Requirement already satisfied: absl-py<2,>=0.15 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (1.4.0)
# Requirement already satisfied: anyio<4,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (3.7.1)
# Requirement already satisfied: cachetools<6,>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (5.3.3)
# Requirement already satisfied: catboost<1.3,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (1.2.5)
# Requirement already satisfied: cloudpickle>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (2.2.1)
# Requirement already satisfied: fsspec[http]<2024,>=2022.11 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (2023.6.0)
# Requirement already satisfied: importlib-resources<7,>=6.1.1 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (6.4.0)
# Requirement already satisfied: numpy<2,>=1.23 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (1.25.2)
# Requirement already satisfied: packaging<24,>=20.9 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (23.2)
# Requirement already satisfied: pandas<3,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (2.0.3)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (14.0.2)
# Requirement already satisfied: pytimeparse<2,>=1.1.8 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (1.1.8)
# Requirement already satisfied: pyyaml<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (6.0.1)
# Requirement already satisfied: retrying<2,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (1.3.4)
# Requirement already satisfied: s3fs<2024,>=2022.11 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (2023.6.0)
# Requirement already satisfied: scikit-learn<1.4,>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (1.2.2)
# Requirement already satisfied: scipy<2,>=1.9 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (1.11.4)
# Requirement already satisfied: snowflake-connector-python[pandas]<4,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (3.10.0)
# Requirement already satisfied: snowflake-snowpark-python!=1.12.0,<2,>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (1.15.0)
# Requirement already satisfied: sqlparse<1,>=0.4 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (0.5.0)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (4.11.0)
# Requirement already satisfied: xgboost<2,>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from snowflake-ml-python) (1.7.6)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->snowflake-ml-python) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->snowflake-ml-python) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->snowflake-ml-python) (1.2.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost<1.3,>=1.2.0->snowflake-ml-python) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost<1.3,>=1.2.0->snowflake-ml-python) (3.7.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost<1.3,>=1.2.0->snowflake-ml-python) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost<1.3,>=1.2.0->snowflake-ml-python) (1.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2024,>=2022.11->snowflake-ml-python) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2024,>=2022.11->snowflake-ml-python) (3.9.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.0.0->snowflake-ml-python) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.0.0->snowflake-ml-python) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.0.0->snowflake-ml-python) (2024.1)
# Requirement already satisfied: aiobotocore~=2.5.0 in /usr/local/lib/python3.10/dist-packages (from s3fs<2024,>=2022.11->snowflake-ml-python) (2.5.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.4,>=1.2.1->snowflake-ml-python) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.4,>=1.2.1->snowflake-ml-python) (3.5.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (1.16.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (42.0.5)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (24.1.0)
# Requirement already satisfied: pyjwt<3.0.0 in /usr/lib/python3/dist-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (2024.2.2)
# Requirement already satisfied: filelock<4,>=3.5 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (3.14.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (4.2.1)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.10/dist-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (0.12.4)
# Requirement already satisfied: setuptools>=40.6.0 in /usr/local/lib/python3.10/dist-packages (from snowflake-snowpark-python!=1.12.0,<2,>=1.11.1->snowflake-ml-python) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from snowflake-snowpark-python!=1.12.0,<2,>=1.11.1->snowflake-ml-python) (0.43.0)
# Requirement already satisfied: botocore<1.31.18,>=1.31.17 in /usr/local/lib/python3.10/dist-packages (from aiobotocore~=2.5.0->s3fs<2024,>=2022.11->snowflake-ml-python) (1.31.17)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.10/dist-packages (from aiobotocore~=2.5.0->s3fs<2024,>=2022.11->snowflake-ml-python) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from aiobotocore~=2.5.0->s3fs<2024,>=2022.11->snowflake-ml-python) (0.11.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (4.0.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (2.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (1.26.18)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost<1.3,>=1.2.0->snowflake-ml-python) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost<1.3,>=1.2.0->snowflake-ml-python) (8.2.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.31.18,>=1.31.17->aiobotocore~=2.5.0->s3fs<2024,>=2022.11->snowflake-ml-python) (1.0.1)

# %% [markdown]
# ### Setup Connection

# %%
from snowflake.snowpark import Session
import numpy as np
import pandas as pd
# from googletrans import Translator
from snowflake.snowpark.functions import year, month, dayofmonth, dayofweek, to_varchar
import snowflake.ml.modeling.preprocessing as snowml
from snowflake.snowpark.functions import col,sum as sum_, when, avg, median
from snowflake.snowpark.functions import count, lit, min, max
from snowflake.snowpark.types import IntegerType, FloatType, DoubleType, DecimalType, StringType, DateType, TimestampType, LongType
import matplotlib.pyplot as plt
import seaborn as sns

# %%
connection_parameters_2 = {
...    "account": "YEZEPEO-DATASCIENCE",
...    "user": "VNSHARED",
...    "password": "Columbia2024!",
...    "role": "SYSADMIN", # optional
...    "warehouse": "ANALYSIS", # optional
...   "database": "MEIXI_DATA", # optional
...   "schema":"PUBLIC",  # optional
...  }

# %%
new_session = Session.builder.configs(connection_parameters_2).create()

# %% [markdown]
# ## Join Vespucio and equifax data

# %% [markdown]
# #### Joined Equifax and exported to Snowflake as FINAL_DATA_JOINED no need to run again

# %%
# df_consolidated=new_session.sql('select * from PUBLIC.CONSOLIDATED_COPY')
# df_equifax = new_session.sql('select * from PUBLIC.EQUIFAX_COPY')

# # Finding Common columns
# common_cols = np.intersect1d(df_consolidated.columns, df_equifax.columns)

# # Printing common columns
# print ("Common Columns:",common_cols)

# df_con_equifax=df_consolidated.join(df_equifax.select('"RUT"', '"Score Equifax"'), on='"RUT"', how='left').drop(df_equifax['"FechaExtraccion"'])

# # Define the new column name for the second column
# new_column_name = 'FechaExtraccion'

# # Use withColumnRenamed to create a new DataFrame with the renamed column
# df_con_equifax_v = df_con_equifax.withColumnRenamed(df_con_equifax.columns[1], new_column_name)


# # Define the name of the table you want to create or overwrite in Snowflake
# table_name = 'FINAL_DATA_JOINED'

# # Write the DataFrame to a new table in Snowflake
# df_con_equifax_v.write.mode('overwrite').save_as_table(table_name)

# %%
def dataset_shape(df):
    # Get the number of rows
    num_rows = df.count()
    # Get the number of columns
    num_columns = len(df.columns)
    # Shape of the DataFrame
    shape = (num_rows, num_columns)
    print("Shape of the given dataset", shape)

# %%
df_final = new_session.sql('select * from PUBLIC.FINAL_DATA_JOINED')

# %%
df_final.show()
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"RUT"       |"FECHAEXTRACCION"  |"NumeroFolio"  |"FechaEmision"  |"FechaVencimiento"  |"FechaRegistro"  |"BusinessPartnerId"  |"CuentaContrato"  |"ClaveReconciliacion"  |"Cabecera_FechaHoraCreacion"  |"Cabecera_FechaHoraUltimaModificacion"  |"PosicionDocumento"  |"ImportePesos"  |"DocumentoCompensacion"  |"FechaCompensacion"  |"DiasCompensacion"  |"OperacionPrincipal"  |"OperacionParcial"  |"Detalle_FechaHoraCreacion"  |"Detalle_FechaHoraUltimaModificacion"  |"Direccion"                   |"COMUNA"     |"CIUDAD"    |"REGION"  |"Nombre"                          |"CantidadCuentasContrato"  |"MaxCategoriaVehiculo"  |"CantidadVehiculos"  |"TramoMoraCliente"  |"TramoMora"  |"Inhabilitado"  |"Concesionaria"  |"TipoCliente"  |"TipoOperacion"  |"TipoDocumento"  |"TipoProducto"  |"StatusCompensacion"  |"StatusCompensacionTmp"  |"Score Equifax"  |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |9292257-K   |52450585684.0      |10499106.0     |2017-11-06      |2017-11-21          |2017-11-05       |0010220399           |001000191051      |17309FA010AU           |2021-04-25 03:30:46           |NULL                                    |3000.0               |981.0           |900201715388.0           |2017-11-23           |2.0                 |0100                  |0002                |2021-04-25 03:30:46          |NULL                                   |SANTORINI ORIENTE 1382        |PUENTE ALTO  |CORDILLERA  |13        |ISMAEL ENRIQUE BORQUEZ RODRIGUEZ  |2                          |1.00000                 |9                    |Pago                |Pago         |Cliente Tag     |AVN              |Natural        |Peaje            |Boleta           |Tag             |Pagada                |Pagada                   |487.0            |
# |10788037-2  |13202514463.0      |27241878.0     |2022-05-16      |2022-05-31          |2022-05-17       |0010020680           |001101916489      |22136FA040AH           |2022-05-18 07:03:14           |2022-05-31 07:10:21                     |1000.0               |4552.0          |301002312583.0           |2022-05-29           |-2.0                |0100                  |0002                |2022-05-18 07:03:14          |2022-05-31 07:10:21                    |EULOGIO ALTAMIRANO 7438       |LA CISTERNA  |SANTIAGO    |13        |JACQUELINE ROXANA CISTERNAS .     |2                          |1.00000                 |1                    |Pago                |Pago         |Cliente Tag     |AVN              |Natural        |Peaje            |Boleta           |Tag             |Pagada                |Pagada                   |397.0            |
# |10788037-2  |13202514463.0      |27241878.0     |2022-05-16      |2022-05-31          |2022-05-17       |0010020680           |001101916489      |22136FA040AH           |2022-05-18 07:03:14           |2022-05-31 07:10:21                     |1001.0               |1.0             |9150107875.0             |2022-05-17           |-14.0               |0100                  |0002                |2022-05-18 07:03:14          |NULL                                   |EULOGIO ALTAMIRANO 7438       |LA CISTERNA  |SANTIAGO    |13        |JACQUELINE ROXANA CISTERNAS .     |2                          |1.00000                 |1                    |Pago                |Pago         |Cliente Tag     |AVN              |Natural        |Peaje            |Boleta           |Tag             |Pagada                |Pagada                   |397.0            |
# |10788037-2  |13202514463.0      |27241878.0     |2022-05-16      |2022-05-31          |2022-05-17       |0010020680           |001101916489      |22136FA040AH           |2022-05-18 07:03:14           |2022-05-31 07:10:21                     |2000.0               |578.0           |301002312583.0           |2022-05-29           |-2.0                |0100                  |0002                |2022-05-18 07:03:14          |2022-05-31 07:10:21                    |EULOGIO ALTAMIRANO 7438       |LA CISTERNA  |SANTIAGO    |13        |JACQUELINE ROXANA CISTERNAS .     |2                          |1.00000                 |1                    |Pago                |Pago         |Cliente Tag     |AVN              |Natural        |Peaje            |Boleta           |Tag             |Pagada                |Pagada                   |397.0            |
# |20284625-4  |53351372667.0      |77840674.0     |2023-10-11      |2023-10-26          |2023-10-11       |0012997499           |001102319465      |23283FA030AE           |2023-10-12 06:10:56           |2023-10-16 06:03:18                     |2000.0               |1201.0          |301562549033.0           |2023-10-14           |-12.0               |0100                  |0002                |2023-10-12 06:10:56          |2023-10-16 06:03:18                    |FRANCISCO BULNES CORREA 2470  |LAS CONDES   |SANTIAGO    |13        |TOMAS BENJAMIN BLANCO GARCIA      |1                          |1.00000                 |1                    |Pago                |Pago         |Cliente Tag     |TSC              |Natural        |Peaje            |Boleta Exenta    |Tag             |Pagada                |Pagada                   |887.0            |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
dataset_shape(df_final)
# Out:
# Shape of the given dataset (482705441, 39)

# %%
def data_prepocessing(df):
  df = df.with_column("YEAR_INVOICED", to_varchar(year(col('"FechaEmision"'))))\
                          .with_column("MONTH_INVOICED", to_varchar(month(col('"FechaEmision"'))))\
                          .with_column("DAY_OF_MONTH_INVOICED", to_varchar(dayofmonth(col('"FechaEmision"'))))\
                          .with_column("DAY_OF_WEEK_INVOICED", to_varchar(dayofweek(col('"FechaEmision"'))))\

  df = df.filter(col("RUT").is_not_null())
  df = df.filter(col('"TipoOperacion"')=='Peaje')
  df = df.withColumn('Unpaid', when(col('"StatusCompensacion"') == 'Pagada', 0).otherwise(1))


  result_customer_span= df.groupBy('"BusinessPartnerId"').agg(
      (max(col("YEAR_INVOICED")) - min(col("YEAR_INVOICED"))).alias("Customer_Lifespan")
  )


  df = df.filter((col('YEAR_INVOICED') == 2023)|(col('YEAR_INVOICED') == 2022)|(col('YEAR_INVOICED') == 2021))

  #dropping unique identifiers
  columns_to_drop_ui = ['"NumeroDocumento"', '"NumeroFolio"', '"RUT"','"CuentaContrato"','"StatusCompensacionTmp"','"FechaRegistro"',
                        '"ClaveReconciliacion"','"Cabecera_FechaHoraCreacion"','"Detalle_FechaHoraCreacion"','"Direccion"','"Nombre"','FECHAEXTRACCION',
                        '"DocumentoCompensacion"','"PosicionDocumento"']

  df = df.drop(*columns_to_drop_ui)

  #over 70% missing values
  columns_to_drop_mv=['"Cabecera_FechaHoraUltimaModificacion"', '"Detalle_FechaHoraUltimaModificacion"']
  df = df.drop(*columns_to_drop_mv)

  #redundant information- TipoOperacion contains the same information
  columns_to_drop3=['"OperacionPrincipal"','"OperacionParcial"','"TramoMora"','"StatusCompensacion"','"COMUNA"', '"REGION"', '"TramoMoraCliente"','"YEAR_INVOICED"',"DAY_OF_MONTH_INVOICED",'"TipoOperacion"']
  df = df.drop(*columns_to_drop3)


  df = df.with_column('"MaxCategoriaVehiculo"', col('"MaxCategoriaVehiculo"').astype("string"))
  # df.set_index(['BusinessPartnerId','DiasCompensacion'], inplace=True)

  schema = df.schema

  numerical_columns = []
  categorical_columns = []
  datetime_columns=[]

  # Iterate over the schema and check the data type of each column
  for field in schema.fields:
    #print(field.datatype)
    if isinstance(field.datatype, (IntegerType, FloatType, DoubleType, DecimalType, LongType)):
        numerical_columns.append(field.name)
    elif isinstance(field.datatype, StringType):
        categorical_columns.append(field.name)
    elif isinstance(field.datatype, (TimestampType, DateType)):
        datetime_columns.append(field.name)

  df = df.drop(*datetime_columns)

  df_with_lifespan=df.join(result_customer_span.select('"BusinessPartnerId"', "CUSTOMER_LIFESPAN"), on='"BusinessPartnerId"', how='left')

  df_with_lifespan = df_with_lifespan.drop('"DiasCompensacion"')
  df_with_lifespan = df_with_lifespan.drop('"BusinessPartnerId"')

  return df_with_lifespan

# %%
df_processed= data_prepocessing(df_final)

# %%
df_processed.show()
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"ImportePesos"  |"CIUDAD"  |"CantidadCuentasContrato"  |"CantidadVehiculos"  |"Inhabilitado"  |"Concesionaria"  |"TipoCliente"  |"TipoDocumento"  |"TipoProducto"  |"Score Equifax"  |"MONTH_INVOICED"  |"DAY_OF_WEEK_INVOICED"  |"UNPAID"  |"MaxCategoriaVehiculo"  |"CUSTOMER_LIFESPAN"  |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |828.0           |SANTIAGO  |2                          |17                   |Cliente Tag     |TSC              |Natural        |Boleta           |Tag             |638.0            |8                 |4                       |0         |1.00000                 |9.0                  |
# |286.0           |SANTIAGO  |2                          |17                   |Cliente Tag     |AVN              |Natural        |Boleta           |Tag             |638.0            |8                 |4                       |0         |1.00000                 |9.0                  |
# |-6.0            |SANTIAGO  |2                          |17                   |Cliente Tag     |AVN              |Natural        |Boleta           |Tag             |638.0            |8                 |4                       |0         |1.00000                 |9.0                  |
# |6.0             |SANTIAGO  |2                          |17                   |Cliente Tag     |AVN              |Natural        |Boleta           |Tag             |638.0            |8                 |4                       |0         |1.00000                 |9.0                  |
# |537.0           |SANTIAGO  |2                          |17                   |Cliente Tag     |AVN              |Natural        |Boleta           |Tag             |638.0            |8                 |4                       |0         |1.00000                 |9.0                  |
# |541.0           |SANTIAGO  |2                          |17                   |Cliente Tag     |AVN              |Natural        |Boleta           |Tag             |638.0            |8                 |4                       |0         |1.00000                 |9.0                  |
# |541.0           |SANTIAGO  |2                          |17                   |Cliente Tag     |AVN              |Natural        |Boleta           |Tag             |638.0            |8                 |4                       |0         |1.00000                 |9.0                  |
# |541.0           |SANTIAGO  |2                          |17                   |Cliente Tag     |AVN              |Natural        |Boleta           |Tag             |638.0            |8                 |4                       |0         |1.00000                 |9.0                  |
# |7206.0          |SANTIAGO  |2                          |17                   |Cliente Tag     |AVN              |Natural        |Boleta           |Tag             |638.0            |8                 |4                       |0         |1.00000                 |9.0                  |
# |2170.0          |SANTIAGO  |2                          |5                    |Cliente Tag     |AVN              |Natural        |Boleta           |Tag             |117.0            |8                 |4                       |0         |1.00000                 |18.0                 |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# result_df = df.groupBy('"TipoOperacion"').agg(
#     (avg(col("UNPAID")) * 100).alias("Default_Percentage")
# )

# result_df.show()

# %%
dataset_shape(df_processed)
# Out:
# Shape of the given dataset (102092363, 15)

# %%
sampled_df = df_processed.sample(0.01)
dataset_shape(sampled_df)
# Out:
# Shape of the given dataset (1021339, 15)

# %%
pandas_df = sampled_df.to_pandas()

# %%
pandas_df.head()
# Out:
#    ImportePesos    CIUDAD  CantidadCuentasContrato  CantidadVehiculos  \
# 0        6316.0  SANTIAGO                        1                8.0
# 1         759.0  SANTIAGO                        2                4.0
# 2         656.0  SANTIAGO                        2                8.0
# 3       14634.0  SANTIAGO                        2                7.0
# 4        7082.0  SANTIAGO                        1                1.0
#
#    Inhabilitado Concesionaria TipoCliente TipoDocumento TipoProducto  \
# 0   Cliente Tag           AVN     Natural        Boleta          Tag
# 1   Cliente Tag           AVN     Natural        Boleta          Tag
# 2   Cliente Tag           AVN     Natural        Boleta          Tag
# 3   Cliente Tag           AVN    Juridico       Factura          Tag
# 4  Inhabilitado           AVN     Natural        Boleta          Tag
#
#    Score Equifax MONTH_INVOICED DAY_OF_WEEK_INVOICED  UNPAID  \
# 0           31.0              6                    3       1
# 1          355.0              6                    2       1
# 2          670.0              6                    3       1
# 3          999.0              9                    4       0
# 4          472.0              7                    4       1
#
#   MaxCategoriaVehiculo  CUSTOMER_LIFESPAN
# 0              1.00000               17.0
# 1              2.00000               10.0
# 2              2.00000               17.0
# 3              1.00000                2.0
# 4              1.00000                5.0

# %%
pandas_df.dropna(inplace=True)

# %%
pandas_df.shape
# Out:
# (986099, 15)

# %%
pandas_df.columns
# Out:
# Index(['ImportePesos', 'CIUDAD', 'CantidadCuentasContrato',
#        'CantidadVehiculos', 'Inhabilitado', 'Concesionaria', 'TipoCliente',
#        'TipoDocumento', 'TipoProducto', 'Score Equifax', 'MONTH_INVOICED',
#        'DAY_OF_WEEK_INVOICED', 'UNPAID', 'MaxCategoriaVehiculo',
#        'CUSTOMER_LIFESPAN'],
#       dtype='object')

# %%
pandas_df['UNPAID'].value_counts(normalize=True)
# Out:
# UNPAID
# 0    0.880657
# 1    0.119343
# Name: proportion, dtype: float64

# %%
model_data=pandas_df.copy()

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
def train_test(df, target_column,test_size=0.2, random_state=42):

    #df.dropna(inplace=True)

    numerical_cols_scaling= ['ImportePesos','Score Equifax','CantidadVehiculos','CantidadCuentasContrato','CUSTOMER_LIFESPAN']

    # Initialize scalers
    scaler_standard = StandardScaler()
    scaler_minmax = MinMaxScaler()

    # Apply standardization and normalization
    df[numerical_cols_scaling] = scaler_standard.fit_transform(df[numerical_cols_scaling])
    df[numerical_cols_scaling] = scaler_minmax.fit_transform(df[numerical_cols_scaling])

    # Convert categorical variables to dummy variables
    df_encoded = pd.get_dummies(df.drop(target_column, axis=1))
    df_encoded.columns = ["".join(c if c.isalnum() else "_" for c in str(x)) for x in df_encoded.columns]


    # Features and Target
    X = df_encoded
    y = df[target_column]

    # Splitting the dataset into the Training set and Test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    return X,y, X_train, X_test, y_train, y_test

# %%
def evaluate_model(model_classifier, X_train, X_test, y_train, y_test):

  # Initialize and train the XGBoost classifier

    # X_train_use=X_train.drop(columns=['BusinessPartnerId','DiasCompensacion'])
    # X_test_use=X_test.drop(columns=['BusinessPartnerId','DiasCompensacion'])


    # print(X_train_use)
    model = model_classifier
    model.fit(X_train, y_train)

    # Evaluate the model
    y_pred = model.predict(X_test)

    y_proba = model.predict_proba(X_test)

    prob_df = pd.DataFrame(y_proba, columns=['Prob_Class_{}'.format(i) for i in range(y_proba.shape[1])])

    prob_df.index = X_test.index

    # Calculating various performance metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='binary')  # Adjust 'binary' if you have a multi-class classification
    recall = recall_score(y_test, y_pred, average='binary')
    f1 = f1_score(y_test, y_pred, average='binary')
    conf_matrix = confusion_matrix(y_test, y_pred)

    # cv_results = model.cv(dtrain=data_dmatrix, params=params, nfold=5,
    #                 num_boost_round=50, early_stopping_rounds=10, metrics="auc",
    #                 as_pandas=True, seed=123)

# Output
# print("AUC (mean): %f" % (cv_results["test-auc-mean"].tail(1)))

    # Printing the metrics
    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"F1 Score: {f1}")
    print(f"Confusion Matrix:\n{conf_matrix}")

    # Returning the model and metrics in a dictionary
    return {
        'model': model,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'confusion_matrix': conf_matrix,
        'predicted_prob':prob_df,
        'y_pred':y_pred,
        'y_test':y_test

    }

# %%
X,y, X_train, X_test, y_train, y_test= train_test(model_data, 'UNPAID')

# %%
X_test.isna().sum()
# Out:
# ImportePesos                    0
# CantidadCuentasContrato         0
# CantidadVehiculos               0
# Score_Equifax                   0
# CUSTOMER_LIFESPAN               0
#                                ..
# DAY_OF_WEEK_INVOICED_6          0
# MaxCategoriaVehiculo_0_00000    0
# MaxCategoriaVehiculo_1_00000    0
# MaxCategoriaVehiculo_2_00000    0
# MaxCategoriaVehiculo_3_00000    0
# Length: 100, dtype: int64

# %%
X_test.head()
# Out:
#         ImportePesos  CantidadCuentasContrato  CantidadVehiculos  \
# 579197      0.408958                 0.000000           0.000047
# 383648      0.408956                 0.000000           0.000000
# 736568      0.409032                 0.016949           0.003277
# 206575      0.409209                 0.000000           0.000047
# 466320      0.408958                 0.016949           0.000665
#
#         Score_Equifax  CUSTOMER_LIFESPAN  CIUDAD_AISEN  CIUDAD_ANTARTICA  \
# 579197       0.493988           0.555556         False             False
# 383648       0.625251           0.166667         False             False
# 736568       0.626253           0.944444         False             False
# 206575       0.467936           0.666667         False             False
# 466320       0.000000           1.000000         False             False
#
#         CIUDAD_ANTOFAGASTA  CIUDAD_ARAUCO  CIUDAD_ARICA  ...  \
# 579197               False          False         False  ...
# 383648               False          False         False  ...
# 736568               False          False         False  ...
# 206575               False          False         False  ...
# 466320               False          False         False  ...
#
#         DAY_OF_WEEK_INVOICED_1  DAY_OF_WEEK_INVOICED_2  \
# 579197                    True                   False
# 383648                   False                    True
# 736568                   False                   False
# 206575                   False                   False
# 466320                   False                    True
#
#         DAY_OF_WEEK_INVOICED_3  DAY_OF_WEEK_INVOICED_4  \
# 579197                   False                   False
# 383648                   False                   False
# 736568                    True                   False
# 206575                   False                   False
# 466320                   False                   False
#
#         DAY_OF_WEEK_INVOICED_5  DAY_OF_WEEK_INVOICED_6  \
# 579197                   False                   False
# 383648                   False                   False
# 736568                   False                   False
# 206575                    True                   False
# 466320                   False                   False
#
#         MaxCategoriaVehiculo_0_00000  MaxCategoriaVehiculo_1_00000  \
# 579197                         False                          True
# 383648                         False                          True
# 736568                         False                         False
# 206575                         False                          True
# 466320                         False                         False
#
#         MaxCategoriaVehiculo_2_00000  MaxCategoriaVehiculo_3_00000
# 579197                         False                         False
# 383648                         False                         False
# 736568                         False                          True
# 206575                         False                         False
# 466320                          True                         False
#
# [5 rows x 100 columns]

# %%
results_xgb=evaluate_model(xgb.XGBClassifier(),X_train, X_test, y_train, y_test)
# Out:
# Accuracy: 0.8909339823547308
# Precision: 0.6995114006514658
# Recall: 0.1463996591393268
# F1 Score: 0.24212529067718974
# Confusion Matrix:
# [[172274   1476]
#  [ 20034   3436]]

# %%
from sklearn.feature_selection import SelectFromModel

# Create a selector object that will use the XGBoost model to identify features that have an importance
# of more than a threshold (here set automatically to mean importance as an example)
selector = SelectFromModel(results_xgb.get('model'), threshold='mean', prefit=True)

# Transform the dataset
X_transformed = selector.transform(X_train)

# Get the features that pass the threshold
selected_features = X.columns[selector.get_support()]

print("Selected features based on threshold:", selected_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Selected features based on threshold: Index(['ImportePesos', 'CantidadCuentasContrato', 'CantidadVehiculos',
#        'Score_Equifax', 'CUSTOMER_LIFESPAN', 'CIUDAD_BIOBIO', 'CIUDAD_CAUTIN',
#        'CIUDAD_COPIAPO', 'CIUDAD_LOS_ANDES', 'CIUDAD_VALPARAISO',
#        'Inhabilitado_Cliente_Tag', 'Concesionaria_AVN', 'TipoCliente_Juridico',
#        'TipoDocumento_Boleta', 'TipoDocumento_Nota_debito',
#        'MONTH_INVOICED_11', 'MONTH_INVOICED_12', 'DAY_OF_WEEK_INVOICED_2',
#        'DAY_OF_WEEK_INVOICED_4', 'MaxCategoriaVehiculo_1_00000'],
#       dtype='object')

# %%
xgb_prob=results_xgb.get('predicted_prob')
xgb_pred=results_xgb.get('y_pred')
xgb_actual=results_xgb.get('y_test')
xgb_actual=xgb_actual.reset_index()
xgb_prob.reset_index(inplace=True)
xgb_prob['Predicted Default']=xgb_pred
xgb_prob['Actual_Default'] = xgb_actual['UNPAID']

# %%
# len(xgb_pred)
# len(xgb_actual)

# %%
xgb_prob
# Out:
#        index  Prob_Class_0  Prob_Class_1  Predicted Default  Actual_Default
# 0      34861      0.999968  3.157515e-05                  0               0
# 1      68726      0.920745  7.925513e-02                  0               0
# 2      15393      1.000000  1.309881e-07                  0               0
# 3      45584      0.953440  4.656000e-02                  0               1
# 4       1747      0.857489  1.425113e-01                  0               0
# ...      ...           ...           ...                ...             ...
# 20442  25588      0.966033  3.396687e-02                  0               0
# 20443  42144      0.435432  5.645676e-01                  1               1
# 20444  90627      0.999974  2.589307e-05                  0               0
# 20445  17102      0.946394  5.360564e-02                  0               0
# 20446  67502      0.839256  1.607438e-01                  0               0
#
# [20447 rows x 5 columns]

# %%
fig, ax = plt.subplots()

# Scatter plot differentiating predicted and actual defaults
for (predicted, actual), group in xgb_prob.groupby(['Predicted Default', 'Actual_Default']):
    label = f'Predicted: {predicted}, Actual: {actual}'
    ax.scatter(group['DiasCompensacion'], group['Prob_Class_1'], label=label, alpha=0.7, edgecolors='w')

# Handling NaN values in 'DiasCompensacion' if any
# df.dropna(subset=['DiasCompensacion'], inplace=True)

# Plot decorations
ax.set_xlabel('DiasCompensacion')
ax.set_ylabel('Prob_Class_1')
ax.set_title('DiasCompensacion vs. Predicted Probability of Class 1')
ax.legend(title='Default Status')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# @title DiasCompensacion vs Prob_Class_0

sns.scatterplot(data=xgb_prob, x='DiasCompensacion', y='Prob_Class_1', hue='Actual_Default', s=32, alpha=0.8)

# Optional: Adjust the legend and the axis spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %%
# Creating the joint density plot
sns.jointplot(x="DiasCompensacion", y="Prob_Class_1", data=xgb_prob, kind="kde", fill=True,hue='Predicted Default')

# Additional customization
plt.suptitle('Joint Density Plot of DiasCompensacion and Prob_Class_1', fontsize=16)
plt.subplots_adjust(top=0.95)  # Adjust the title to not overlap with plots

# Display the plot
plt.show()

# %%
# Plotting the feature importance for 'weight'
xgb.plot_importance(results_xgb.get('model'), importance_type='weight', title='Feature Importance: Weight', max_num_features=25)
plt.show()

# %%
# Plotting the feature importance for 'gain'
xgb.plot_importance(results_xgb.get('model'), importance_type='gain', title='Feature Importance: Gain', max_num_features=25)
plt.show()

# %%
results_randomforest=evaluate_model(RandomForestClassifier(),X_train, X_test, y_train, y_test)
# Out:
# Accuracy: 0.88552378054964
# Precision: 0.5696242008420396
# Recall: 0.15564550489987217
# F1 Score: 0.2444868319780477
# Confusion Matrix:
# [[170990   2760]
#  [ 19817   3653]]

# %%
importances = results_randomforest.get('model').feature_importances_
indices = np.argsort(importances)[-25:]  # Top 25 features

# Plot the feature importances of the forest
plt.figure(figsize=(10, 8))
plt.title('Top 25 Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [X_train.columns[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
results_lgbm=evaluate_model(lgb.LGBMClassifier(),X_train, X_test, y_train, y_test)
# Out:
# [LightGBM] [Info] Number of positive: 94214, number of negative: 694665
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.437364 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 914
# [LightGBM] [Info] Number of data points in the train set: 788879, number of used features: 91
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.119428 -> initscore=-1.997861
# [LightGBM] [Info] Start training from score -1.997861
# Accuracy: 0.8896866443565561
# Precision: 0.7297587131367292
# Recall: 0.11597784405624201
# F1 Score: 0.20014705882352943
# Confusion Matrix:
# [[172742   1008]
#  [ 20748   2722]]

# %%
# Get feature importances
importances = results_lgbm.get('model').feature_importances_
feature_names = X_train.columns
feature_imports = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_imports = feature_imports.sort_values(by='Importance', ascending=False).head(25)  # top 25 features

# Plot feature importances
plt.figure(figsize=(10, 8))
plt.barh(feature_imports['Feature'], feature_imports['Importance'], color='green')
plt.xlabel('Importance')
plt.title('Top 25 Feature Importances - LightGBM')
plt.gca().invert_yaxis()  # Invert y axis to have the most important at the top
plt.show()

# %%
lgbm_prob=results_lgbm.get('predicted_prob')
lgbm_pred=results_lgbm.get('y_pred')
lgbm_actual=results_lgbm.get('y_test')
lgbm_actual=lgbm_actual.reset_index()
lgbm_prob.reset_index(inplace=True)
lgbm_prob['Predicted Default']=xgb_pred
lgbm_prob['Actual_Default'] = lgbm_actual['UNPAID']

# %%
fig, ax = plt.subplots()

# Scatter plot differentiating predicted and actual defaults
for (predicted, actual), group in lgbm_prob.groupby(['Predicted Default', 'Actual_Default']):
    label = f'Predicted: {predicted}, Actual: {actual}'
    ax.scatter(group['DiasCompensacion'], group['Prob_Class_1'], label=label, alpha=0.7, edgecolors='w')

# Handling NaN values in 'DiasCompensacion' if any
# lgbm_prob.dropna(subset=['DiasCompensacion'], inplace=True)

# Plot decorations
ax.set_xlabel('DiasCompensacion')
ax.set_ylabel('Prob_Class_1')
ax.set_title('DiasCompensacion vs. Predicted Probability of Class 1')
ax.legend(title='Default Status')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.linear_model import LogisticRegression
results_logit=evaluate_model(LogisticRegression(random_state=0,max_iter=200,solver='sag'),X_train, X_test, y_train, y_test)
# Out:
# Accuracy: 0.8850623668999087
# Precision: 0.7213024282560706
# Recall: 0.055688112484022154
# F1 Score: 0.10339371885135669
# Confusion Matrix:
# [[173245    505]
#  [ 22163   1307]]

# %%
# Extract coefficients
coefficients = results_logit.get('model').coef_[0]  # Get the coefficients corresponding to each feature
features = X_train.columns  # Feature names

# Create a DataFrame of features and their corresponding coefficients
feature_importance = pd.DataFrame({'Feature': features, 'Coefficient': coefficients})

# Sort the features by the absolute value of their coefficients
feature_importance['Absolute Coefficient'] = feature_importance['Coefficient'].abs()
feature_importance = feature_importance.sort_values(by='Absolute Coefficient', ascending=False).head(25)

# Plotting
plt.figure(figsize=(8, 5))
feature_importance.sort_values(by='Absolute Coefficient').plot.barh(x='Feature', y='Coefficient', color='blue')
plt.title('Feature Importance in Logistic Regression')
plt.xlabel('Coefficient Value')
plt.ylabel('Features')
plt.show()

# %%
import statsmodels.api as sm

# %%
X.head()
# Out:
#                                     ImportePesos  CantidadCuentasContrato  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                 0.120431                 0.000000
# 0010169172        -16.0                 0.119254                 0.016949
# 0012011570        NaN                   0.177722                 0.000000
# 0010653204         50.0                 0.119942                 0.016949
# 0010631888        -15.0                 0.121503                 0.000000
#
#                                     CantidadVehiculos  Score_Equifax  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                      0.000047       0.031062
# 0010169172        -16.0                      0.000119       0.943888
# 0012011570        NaN                        0.000047       0.000000
# 0010653204         50.0                      0.000332       0.006012
# 0010631888        -15.0                      0.000404       0.666333
#
#                                     CUSTOMER_LIFESPAN  CIUDAD__  CIUDAD_AISEN  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                      0.166667     False         False
# 0010169172        -16.0                      1.000000     False         False
# 0012011570        NaN                        0.611111     False         False
# 0010653204         50.0                      0.944444     False         False
# 0010631888        -15.0                      0.944444     False         False
#
#                                     CIUDAD_ANTARTICA  CIUDAD_ANTOFAGASTA  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                        False               False
# 0010169172        -16.0                        False               False
# 0012011570        NaN                          False               False
# 0010653204         50.0                        False               False
# 0010631888        -15.0                        False               False
#
#                                     CIUDAD_ARAUCO  ...  \
# BusinessPartnerId DiasCompensacion                 ...
# 0013867255         90.0                     False  ...
# 0010169172        -16.0                     False  ...
# 0012011570        NaN                       False  ...
# 0010653204         50.0                     False  ...
# 0010631888        -15.0                     False  ...
#
#                                     DAY_OF_WEEK_INVOICED_1  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                              False
# 0010169172        -16.0                              False
# 0012011570        NaN                                 True
# 0010653204         50.0                               True
# 0010631888        -15.0                               True
#
#                                     DAY_OF_WEEK_INVOICED_2  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                              False
# 0010169172        -16.0                              False
# 0012011570        NaN                                False
# 0010653204         50.0                              False
# 0010631888        -15.0                              False
#
#                                     DAY_OF_WEEK_INVOICED_3  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                              False
# 0010169172        -16.0                              False
# 0012011570        NaN                                False
# 0010653204         50.0                              False
# 0010631888        -15.0                              False
#
#                                     DAY_OF_WEEK_INVOICED_4  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                              False
# 0010169172        -16.0                              False
# 0012011570        NaN                                False
# 0010653204         50.0                              False
# 0010631888        -15.0                              False
#
#                                     DAY_OF_WEEK_INVOICED_5  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                               True
# 0010169172        -16.0                              False
# 0012011570        NaN                                False
# 0010653204         50.0                              False
# 0010631888        -15.0                              False
#
#                                     DAY_OF_WEEK_INVOICED_6  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                              False
# 0010169172        -16.0                               True
# 0012011570        NaN                                False
# 0010653204         50.0                              False
# 0010631888        -15.0                              False
#
#                                     MaxCategoriaVehiculo_0_00000  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                                    False
# 0010169172        -16.0                                    False
# 0012011570        NaN                                      False
# 0010653204         50.0                                    False
# 0010631888        -15.0                                    False
#
#                                     MaxCategoriaVehiculo_1_00000  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                                     True
# 0010169172        -16.0                                     True
# 0012011570        NaN                                      False
# 0010653204         50.0                                    False
# 0010631888        -15.0                                     True
#
#                                     MaxCategoriaVehiculo_2_00000  \
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                                    False
# 0010169172        -16.0                                    False
# 0012011570        NaN                                       True
# 0010653204         50.0                                     True
# 0010631888        -15.0                                    False
#
#                                     MaxCategoriaVehiculo_3_00000
# BusinessPartnerId DiasCompensacion
# 0013867255         90.0                                    False
# 0010169172        -16.0                                    False
# 0012011570        NaN                                      False
# 0010653204         50.0                                    False
# 0010631888        -15.0                                    False
#
# [5 rows x 100 columns]

# %%
y
# Out:
# BusinessPartnerId  DiasCompensacion
# 0013867255          90.0               0
# 0010169172         -16.0               0
# 0012011570         NaN                 1
# 0010653204          50.0               0
# 0010631888         -15.0               0
#                                       ..
# 0010273843         -3.0                0
#                    -3.0                0
# 0010277305          0.0                0
#                     0.0                0
#                     0.0                0
# Name: UNPAID, Length: 102437, dtype: int8

# %%
logit_data=model_data.copy()
logit_data.drop(columns=['BusinessPartnerId','DiasCompensacion','CIUDAD','TipoDocumento'])
# Out:
#         ImportePesos  CantidadCuentasContrato  CantidadVehiculos Inhabilitado  \
# 0               -5.0                        1                5.0  Cliente Tag
# 1                3.0                        1                4.0  Cliente Tag
# 2               -3.0                        1                1.0  Cliente Tag
# 3              662.0                        1                4.0  Cliente Tag
# 4             1884.0                        2                4.0  Cliente Tag
# ...              ...                      ...                ...          ...
# 101901        2158.0                        1                1.0  Cliente Tag
# 101902         759.0                        2               15.0  Cliente Tag
# 101903       11554.0                        1                1.0  Cliente Tag
# 101904           4.0                        2                5.0  Cliente Tag
# 101905          -7.0                        1                2.0  Cliente Tag
#
#        Concesionaria TipoCliente TipoProducto  Score Equifax MONTH_INVOICED  \
# 0                AVN     Natural          Tag          683.0             10
# 1                AVN     Natural          Tag          966.0              4
# 2                AVN     Natural          Tag           56.0              8
# 3                TSC     Natural          Tag          754.0             10
# 4                TSC     Natural          Tag          563.0              5
# ...              ...         ...          ...            ...            ...
# 101901           AVN     Natural          Tag          799.0              7
# 101902           AVN    Juridico          Tag          999.0              7
# 101903           AVN     Natural          Tag          801.0              9
# 101904           AVN     Natural          Tag          810.0             10
# 101905           AVN     Natural          Tag          879.0              1
#
#        DAY_OF_WEEK_INVOICED  UNPAID MaxCategoriaVehiculo  CUSTOMER_LIFESPAN
# 0                         4       0              1.00000               18.0
# 1                         4       0              1.00000                6.0
# 2                         2       0              1.00000                4.0
# 3                         5       0              1.00000               11.0
# 4                         4       0              1.00000               17.0
# ...                     ...     ...                  ...                ...
# 101901                    5       0              1.00000                3.0
# 101902                    4       0              3.00000               17.0
# 101903                    2       1              1.00000                3.0
# 101904                    4       0              1.00000               17.0
# 101905                    5       0              2.00000                3.0
#
# [101906 rows x 13 columns]

# %%
y_logit =logit_data['UNPAID']
X_logit=logit_data.drop('UNPAID', axis=1)

# %%
# Select features and target
X_logit = pd.get_dummies(X_logit, drop_first=True)
y_logit = y_logit

# %%
# Add a constant to the features for the intercept
X_const = sm.add_constant(X_logit)

# %%
# Fit the logistic regression model
model = sm.Logit(y_logit, X_const)
result = model.fit()

# Display the summary of the model
print(result.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-ca923304fca2> in <cell line: 2>()
#       1 # Fit the logistic regression model
# ----> 2 model = sm.Logit(y_logit, X_const)
#       3 result = model.fit()
#       4
#       5 # Display the summary of the model
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/discrete/discrete_model.py in __init__(self, endog, exog, offset, check_rank, **kwargs)
#     473         # unconditional check, requires no extra kwargs added by subclasses
#     474         self._check_kwargs(kwargs)
# --> 475         super().__init__(endog, exog, offset=offset, check_rank=check_rank,
#     476                          **kwargs)
#     477         if not issubclass(self.__class__, MultinomialModel):
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/discrete/discrete_model.py in __init__(self, endog, exog, check_rank, **kwargs)
#     183     def __init__(self, endog, exog, check_rank=True, **kwargs):
#     184         self._check_rank = check_rank
# --> 185         super().__init__(endog, exog, **kwargs)
#     186         self.raise_on_perfect_prediction = False  # keep for backwards compat
#     187         self.k_extra = 0
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     268
#     269     def __init__(self, endog, exog=None, **kwargs):
# --> 270         super().__init__(endog, exog, **kwargs)
#     271         self.initialize()
#     272
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      93         missing = kwargs.pop('missing', 'none')
#      94         hasconst = kwargs.pop('hasconst', None)
# ---> 95         self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                                       **kwargs)
#      97         self.k_constant = self.data.k_constant
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     133
#     134     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136         # kwargs arrays could have changed, easier to just attach here
#     137         for key in kwargs:
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     673
#     674     klass = handle_data_class_factory(endog, exog)
# --> 675     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676                  **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      82             self.orig_endog = endog
#      83             self.orig_exog = exog
# ---> 84             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      85
#      86         self.const_idx = None
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py in _convert_endog_exog(self, endog, exog)
#     507         exog = exog if exog is None else np.asarray(exog)
#     508         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 509             raise ValueError("Pandas data cast to numpy dtype of object. "
#     510                              "Check input data with np.asarray(data).")
#     511         return super()._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %%
from catboost import CatBoostClassifier

# %%
results_catboost=evaluate_model(CatBoostClassifier(),X_train, X_test, y_train, y_test)
# Out:
# Learning rate set to 0.066447
# 0:	learn: 0.6340676	total: 21ms	remaining: 21s
# 1:	learn: 0.5700339	total: 63.4ms	remaining: 31.6s
# 2:	learn: 0.5278876	total: 112ms	remaining: 37.3s
# 3:	learn: 0.4934948	total: 137ms	remaining: 34s
# 4:	learn: 0.4678320	total: 175ms	remaining: 34.7s
# 5:	learn: 0.4435070	total: 217ms	remaining: 36s
# 6:	learn: 0.4250419	total: 252ms	remaining: 35.7s
# 7:	learn: 0.4098309	total: 274ms	remaining: 34s
# 8:	learn: 0.3976983	total: 301ms	remaining: 33.1s
# 9:	learn: 0.3864161	total: 375ms	remaining: 37.1s
# 10:	learn: 0.3764010	total: 414ms	remaining: 37.2s
# 11:	learn: 0.3615948	total: 438ms	remaining: 36.1s
# 12:	learn: 0.3546748	total: 462ms	remaining: 35.1s
# 13:	learn: 0.3482793	total: 485ms	remaining: 34.2s
# 14:	learn: 0.3425446	total: 525ms	remaining: 34.4s
# 15:	learn: 0.3386496	total: 549ms	remaining: 33.8s
# 16:	learn: 0.3352190	total: 576ms	remaining: 33.3s
# 17:	learn: 0.3318104	total: 599ms	remaining: 32.7s
# 18:	learn: 0.3286436	total: 632ms	remaining: 32.6s
# 19:	learn: 0.3234472	total: 658ms	remaining: 32.2s
# 20:	learn: 0.3209140	total: 681ms	remaining: 31.8s
# 21:	learn: 0.3186202	total: 707ms	remaining: 31.4s
# 259:	learn: 0.2733059	total: 9.5s	remaining: 27s
# 260:	learn: 0.2732641	total: 9.52s	remaining: 27s
# 261:	learn: 0.2732095	total: 9.56s	remaining: 26.9s
# 262:	learn: 0.2731568	total: 9.58s	remaining: 26.8s
# 263:	learn: 0.2731073	total: 9.6s	remaining: 26.8s
# 264:	learn: 0.2730312	total: 9.62s	remaining: 26.7s
# 265:	learn: 0.2729660	total: 9.64s	remaining: 26.6s
# 266:	learn: 0.2729166	total: 9.66s	remaining: 26.5s
# 267:	learn: 0.2727579	total: 9.68s	remaining: 26.4s
# 268:	learn: 0.2727156	total: 9.69s	remaining: 26.3s
# 269:	learn: 0.2726855	total: 9.71s	remaining: 26.3s
# 270:	learn: 0.2726613	total: 9.73s	remaining: 26.2s
# 271:	learn: 0.2725967	total: 9.75s	remaining: 26.1s
# 272:	learn: 0.2725267	total: 9.77s	remaining: 26s
# 273:	learn: 0.2724650	total: 9.79s	remaining: 25.9s
# 274:	learn: 0.2724415	total: 9.81s	remaining: 25.9s
# 275:	learn: 0.2723875	total: 9.82s	remaining: 25.8s
# 276:	learn: 0.2723323	total: 9.85s	remaining: 25.7s
# 277:	learn: 0.2722919	total: 9.87s	remaining: 25.6s
# 278:	learn: 0.2722604	total: 9.89s	remaining: 25.5s
# 279:	learn: 0.2722158	total: 9.9s	remaining: 25.5s
# 280:	learn: 0.2721854	total: 9.92s	remaining: 25.4s
# 281:	learn: 0.2721427	total: 9.94s	remaining: 25.3s
# 282:	learn: 0.2720934	total: 9.96s	remaining: 25.2s
# 283:	learn: 0.2720340	total: 9.98s	remaining: 25.2s
# 284:	learn: 0.2719910	total: 10s	remaining: 25.1s
# 285:	learn: 0.2719612	total: 10s	remaining: 25s
# 286:	learn: 0.2719307	total: 10s	remaining: 24.9s
# 287:	learn: 0.2718923	total: 10.1s	remaining: 24.9s
# 288:	learn: 0.2718445	total: 10.1s	remaining: 24.8s
# 289:	learn: 0.2718067	total: 10.1s	remaining: 24.7s
# 290:	learn: 0.2717561	total: 10.1s	remaining: 24.6s
# 291:	learn: 0.2716975	total: 10.1s	remaining: 24.6s
# 292:	learn: 0.2716796	total: 10.1s	remaining: 24.5s
# 293:	learn: 0.2716300	total: 10.2s	remaining: 24.4s
# 294:	learn: 0.2715917	total: 10.2s	remaining: 24.3s
# 295:	learn: 0.2715450	total: 10.2s	remaining: 24.3s
# 296:	learn: 0.2714645	total: 10.2s	remaining: 24.2s
# 297:	learn: 0.2714164	total: 10.2s	remaining: 24.1s
# 298:	learn: 0.2713952	total: 10.3s	remaining: 24.1s
# 299:	learn: 0.2713520	total: 10.3s	remaining: 24s
# 300:	learn: 0.2713104	total: 10.3s	remaining: 23.9s
# 301:	learn: 0.2712541	total: 10.3s	remaining: 23.9s
# 302:	learn: 0.2712138	total: 10.3s	remaining: 23.8s
# 303:	learn: 0.2711872	total: 10.4s	remaining: 23.7s
# 304:	learn: 0.2711503	total: 10.4s	remaining: 23.7s
# 305:	learn: 0.2711244	total: 10.4s	remaining: 23.6s
# 306:	learn: 0.2711070	total: 10.4s	remaining: 23.5s
# 307:	learn: 0.2710553	total: 10.4s	remaining: 23.5s
# 308:	learn: 0.2710150	total: 10.5s	remaining: 23.4s
# 309:	learn: 0.2709675	total: 10.5s	remaining: 23.3s
# 310:	learn: 0.2709335	total: 10.5s	remaining: 23.3s
# 311:	learn: 0.2708861	total: 10.5s	remaining: 23.2s
# 312:	learn: 0.2708499	total: 10.6s	remaining: 23.2s
# 313:	learn: 0.2707910	total: 10.6s	remaining: 23.1s
# 314:	learn: 0.2707307	total: 10.6s	remaining: 23.1s
# 315:	learn: 0.2707066	total: 10.6s	remaining: 23s
# 316:	learn: 0.2706799	total: 10.6s	remaining: 22.9s
# 317:	learn: 0.2706241	total: 10.7s	remaining: 22.9s
# 318:	learn: 0.2704959	total: 10.7s	remaining: 22.8s
# 319:	learn: 0.2704283	total: 10.7s	remaining: 22.7s
# 320:	learn: 0.2703741	total: 10.7s	remaining: 22.7s
# 321:	learn: 0.2703146	total: 10.7s	remaining: 22.6s
# 322:	learn: 0.2702769	total: 10.8s	remaining: 22.5s
# 323:	learn: 0.2702331	total: 10.8s	remaining: 22.5s
# 324:	learn: 0.2702158	total: 10.8s	remaining: 22.4s
# 325:	learn: 0.2701789	total: 10.8s	remaining: 22.3s
# 326:	learn: 0.2701322	total: 10.8s	remaining: 22.3s
# 327:	learn: 0.2700852	total: 10.8s	remaining: 22.2s
# 328:	learn: 0.2700360	total: 10.9s	remaining: 22.2s
# 329:	learn: 0.2700149	total: 10.9s	remaining: 22.1s
# 330:	learn: 0.2699698	total: 10.9s	remaining: 22.1s
# 331:	learn: 0.2699517	total: 10.9s	remaining: 22s
# 332:	learn: 0.2698787	total: 10.9s	remaining: 21.9s
# 333:	learn: 0.2698313	total: 11s	remaining: 21.9s
# 334:	learn: 0.2697868	total: 11s	remaining: 21.8s
# 335:	learn: 0.2697619	total: 11s	remaining: 21.7s
# 336:	learn: 0.2697062	total: 11s	remaining: 21.7s
# 337:	learn: 0.2696554	total: 11s	remaining: 21.6s
# 338:	learn: 0.2696088	total: 11.1s	remaining: 21.6s
# 339:	learn: 0.2695435	total: 11.1s	remaining: 21.5s
# 340:	learn: 0.2694945	total: 11.1s	remaining: 21.4s
# 341:	learn: 0.2694281	total: 11.1s	remaining: 21.4s
# 342:	learn: 0.2693982	total: 11.1s	remaining: 21.3s
# 343:	learn: 0.2693633	total: 11.2s	remaining: 21.3s
# 344:	learn: 0.2693150	total: 11.2s	remaining: 21.2s
# 345:	learn: 0.2692776	total: 11.2s	remaining: 21.2s
# 346:	learn: 0.2692244	total: 11.2s	remaining: 21.1s
# 347:	learn: 0.2691707	total: 11.2s	remaining: 21.1s
# 348:	learn: 0.2691620	total: 11.3s	remaining: 21s
# 349:	learn: 0.2691193	total: 11.3s	remaining: 21s
# 350:	learn: 0.2690476	total: 11.3s	remaining: 20.9s
# 351:	learn: 0.2690304	total: 11.3s	remaining: 20.8s
# 352:	learn: 0.2689877	total: 11.3s	remaining: 20.8s
# 353:	learn: 0.2689389	total: 11.4s	remaining: 20.7s
# 354:	learn: 0.2688864	total: 11.4s	remaining: 20.7s
# 355:	learn: 0.2688503	total: 11.4s	remaining: 20.6s
# 356:	learn: 0.2688030	total: 11.4s	remaining: 20.6s
# 357:	learn: 0.2687585	total: 11.4s	remaining: 20.5s
# 358:	learn: 0.2687344	total: 11.5s	remaining: 20.5s
# 359:	learn: 0.2686909	total: 11.5s	remaining: 20.4s
# 360:	learn: 0.2686374	total: 11.5s	remaining: 20.4s
# 361:	learn: 0.2686293	total: 11.5s	remaining: 20.3s
# 362:	learn: 0.2685866	total: 11.5s	remaining: 20.2s
# 363:	learn: 0.2685450	total: 11.6s	remaining: 20.2s
# 364:	learn: 0.2684964	total: 11.6s	remaining: 20.2s
# 365:	learn: 0.2684652	total: 11.6s	remaining: 20.1s
# 366:	learn: 0.2684521	total: 11.6s	remaining: 20.1s
# 367:	learn: 0.2684153	total: 11.7s	remaining: 20s
# 368:	learn: 0.2683776	total: 11.7s	remaining: 20s
# 369:	learn: 0.2683181	total: 11.7s	remaining: 19.9s
# 370:	learn: 0.2682968	total: 11.7s	remaining: 19.9s
# 371:	learn: 0.2682340	total: 11.7s	remaining: 19.8s
# 372:	learn: 0.2681761	total: 11.7s	remaining: 19.7s
# 373:	learn: 0.2681368	total: 11.8s	remaining: 19.7s
# 374:	learn: 0.2680594	total: 11.8s	remaining: 19.7s
# 375:	learn: 0.2680255	total: 11.8s	remaining: 19.6s
# 376:	learn: 0.2679661	total: 11.8s	remaining: 19.5s
# 377:	learn: 0.2679345	total: 11.8s	remaining: 19.5s
# 378:	learn: 0.2679039	total: 11.9s	remaining: 19.4s
# 379:	learn: 0.2678719	total: 11.9s	remaining: 19.4s
# 380:	learn: 0.2678667	total: 11.9s	remaining: 19.3s
# 381:	learn: 0.2678213	total: 11.9s	remaining: 19.3s
# 382:	learn: 0.2677774	total: 11.9s	remaining: 19.2s
# 383:	learn: 0.2677405	total: 12s	remaining: 19.2s
# 384:	learn: 0.2677050	total: 12s	remaining: 19.1s
# 385:	learn: 0.2676679	total: 12s	remaining: 19.1s
# 386:	learn: 0.2676198	total: 12s	remaining: 19s
# 387:	learn: 0.2675734	total: 12s	remaining: 19s
# 388:	learn: 0.2675431	total: 12.1s	remaining: 18.9s
# 389:	learn: 0.2675254	total: 12.1s	remaining: 18.9s
# 390:	learn: 0.2674801	total: 12.1s	remaining: 18.8s
# 391:	learn: 0.2674380	total: 12.1s	remaining: 18.8s
# 392:	learn: 0.2674227	total: 12.1s	remaining: 18.7s
# 393:	learn: 0.2673832	total: 12.2s	remaining: 18.7s
# 394:	learn: 0.2673282	total: 12.2s	remaining: 18.6s
# 395:	learn: 0.2672943	total: 12.2s	remaining: 18.6s
# 396:	learn: 0.2672651	total: 12.2s	remaining: 18.6s
# 397:	learn: 0.2672334	total: 12.2s	remaining: 18.5s
# 398:	learn: 0.2671820	total: 12.3s	remaining: 18.5s
# 399:	learn: 0.2671360	total: 12.3s	remaining: 18.4s
# 400:	learn: 0.2670486	total: 12.3s	remaining: 18.4s
# 401:	learn: 0.2670168	total: 12.3s	remaining: 18.3s
# 545:	learn: 0.2619903	total: 15.2s	remaining: 12.6s
# 546:	learn: 0.2619474	total: 15.2s	remaining: 12.6s
# 547:	learn: 0.2618989	total: 15.2s	remaining: 12.6s
# 548:	learn: 0.2618720	total: 15.2s	remaining: 12.5s
# 549:	learn: 0.2618431	total: 15.3s	remaining: 12.5s
# 550:	learn: 0.2618302	total: 15.3s	remaining: 12.4s
# 551:	learn: 0.2617975	total: 15.3s	remaining: 12.4s
# 552:	learn: 0.2617788	total: 15.3s	remaining: 12.4s
# 553:	learn: 0.2617391	total: 15.3s	remaining: 12.3s
# 554:	learn: 0.2616912	total: 15.3s	remaining: 12.3s
# 555:	learn: 0.2616601	total: 15.4s	remaining: 12.3s
# 556:	learn: 0.2616172	total: 15.4s	remaining: 12.2s
# 557:	learn: 0.2615916	total: 15.4s	remaining: 12.2s
# 558:	learn: 0.2615591	total: 15.4s	remaining: 12.2s
# 559:	learn: 0.2615326	total: 15.5s	remaining: 12.1s
# 560:	learn: 0.2614921	total: 15.5s	remaining: 12.1s
# 561:	learn: 0.2614710	total: 15.5s	remaining: 12.1s
# 562:	learn: 0.2614365	total: 15.5s	remaining: 12s
# 563:	learn: 0.2613911	total: 15.5s	remaining: 12s
# 564:	learn: 0.2613534	total: 15.6s	remaining: 12s
# 565:	learn: 0.2613114	total: 15.6s	remaining: 11.9s
# 566:	learn: 0.2612735	total: 15.6s	remaining: 11.9s
# 567:	learn: 0.2612477	total: 15.6s	remaining: 11.9s
# 568:	learn: 0.2612124	total: 15.6s	remaining: 11.9s
# 569:	learn: 0.2611825	total: 15.7s	remaining: 11.8s
# 570:	learn: 0.2611268	total: 15.7s	remaining: 11.8s
# 571:	learn: 0.2610791	total: 15.7s	remaining: 11.8s
# 572:	learn: 0.2610618	total: 15.7s	remaining: 11.7s
# 573:	learn: 0.2609985	total: 15.7s	remaining: 11.7s
# 574:	learn: 0.2609394	total: 15.8s	remaining: 11.7s
# 575:	learn: 0.2609088	total: 15.8s	remaining: 11.6s
# 576:	learn: 0.2608685	total: 15.8s	remaining: 11.6s
# 577:	learn: 0.2608282	total: 15.8s	remaining: 11.5s
# 578:	learn: 0.2607982	total: 15.8s	remaining: 11.5s
# 579:	learn: 0.2607610	total: 15.9s	remaining: 11.5s
# 580:	learn: 0.2607157	total: 15.9s	remaining: 11.5s
# 581:	learn: 0.2606639	total: 15.9s	remaining: 11.4s
# 582:	learn: 0.2606055	total: 15.9s	remaining: 11.4s
# 583:	learn: 0.2605570	total: 15.9s	remaining: 11.4s
# 584:	learn: 0.2605033	total: 16s	remaining: 11.3s
# 585:	learn: 0.2604541	total: 16s	remaining: 11.3s
# 586:	learn: 0.2604202	total: 16s	remaining: 11.3s
# 587:	learn: 0.2603915	total: 16s	remaining: 11.2s
# 588:	learn: 0.2603871	total: 16s	remaining: 11.2s
# 589:	learn: 0.2603677	total: 16.1s	remaining: 11.2s
# 590:	learn: 0.2603167	total: 16.1s	remaining: 11.1s
# 591:	learn: 0.2602578	total: 16.1s	remaining: 11.1s
# 592:	learn: 0.2602301	total: 16.1s	remaining: 11.1s
# 593:	learn: 0.2602073	total: 16.1s	remaining: 11s
# 594:	learn: 0.2601625	total: 16.1s	remaining: 11s
# 595:	learn: 0.2601252	total: 16.2s	remaining: 11s
# 596:	learn: 0.2600887	total: 16.2s	remaining: 10.9s
# 597:	learn: 0.2600350	total: 16.2s	remaining: 10.9s
# 598:	learn: 0.2600051	total: 16.2s	remaining: 10.9s
# 599:	learn: 0.2599688	total: 16.2s	remaining: 10.8s
# 600:	learn: 0.2599071	total: 16.3s	remaining: 10.8s
# 601:	learn: 0.2598785	total: 16.3s	remaining: 10.8s
# 602:	learn: 0.2598724	total: 16.3s	remaining: 10.7s
# 603:	learn: 0.2598535	total: 16.3s	remaining: 10.7s
# 604:	learn: 0.2598322	total: 16.3s	remaining: 10.7s
# 605:	learn: 0.2598154	total: 16.4s	remaining: 10.6s
# 606:	learn: 0.2597703	total: 16.4s	remaining: 10.6s
# 607:	learn: 0.2597385	total: 16.4s	remaining: 10.6s
# 608:	learn: 0.2596931	total: 16.4s	remaining: 10.5s
# 609:	learn: 0.2596466	total: 16.4s	remaining: 10.5s
# 610:	learn: 0.2596453	total: 16.5s	remaining: 10.5s
# 611:	learn: 0.2596073	total: 16.5s	remaining: 10.4s
# 612:	learn: 0.2595814	total: 16.5s	remaining: 10.4s
# 613:	learn: 0.2595371	total: 16.5s	remaining: 10.4s
# 614:	learn: 0.2594871	total: 16.5s	remaining: 10.3s
# 615:	learn: 0.2594643	total: 16.6s	remaining: 10.3s
# 616:	learn: 0.2594163	total: 16.6s	remaining: 10.3s
# 617:	learn: 0.2593804	total: 16.6s	remaining: 10.3s
# 618:	learn: 0.2593302	total: 16.6s	remaining: 10.2s
# 619:	learn: 0.2592750	total: 16.6s	remaining: 10.2s
# 620:	learn: 0.2592476	total: 16.7s	remaining: 10.2s
# 621:	learn: 0.2592081	total: 16.7s	remaining: 10.1s
# 622:	learn: 0.2591827	total: 16.7s	remaining: 10.1s
# 623:	learn: 0.2591523	total: 16.7s	remaining: 10.1s
# 624:	learn: 0.2591097	total: 16.7s	remaining: 10s
# 625:	learn: 0.2590647	total: 16.8s	remaining: 10s
# 626:	learn: 0.2590170	total: 16.8s	remaining: 9.98s
# 627:	learn: 0.2589922	total: 16.8s	remaining: 9.95s
# 628:	learn: 0.2589540	total: 16.8s	remaining: 9.93s
# 629:	learn: 0.2589321	total: 16.8s	remaining: 9.89s
# 630:	learn: 0.2588955	total: 16.9s	remaining: 9.86s
# 631:	learn: 0.2588711	total: 16.9s	remaining: 9.83s
# 632:	learn: 0.2588471	total: 16.9s	remaining: 9.8s
# 633:	learn: 0.2588085	total: 16.9s	remaining: 9.77s
# 634:	learn: 0.2587851	total: 16.9s	remaining: 9.74s
# 635:	learn: 0.2587577	total: 17s	remaining: 9.71s
# 636:	learn: 0.2587541	total: 17s	remaining: 9.68s
# 637:	learn: 0.2587500	total: 17s	remaining: 9.65s
# 638:	learn: 0.2587162	total: 17s	remaining: 9.62s
# 639:	learn: 0.2586928	total: 17s	remaining: 9.59s
# 640:	learn: 0.2586645	total: 17.1s	remaining: 9.56s
# 641:	learn: 0.2586272	total: 17.1s	remaining: 9.53s
# 642:	learn: 0.2586000	total: 17.1s	remaining: 9.5s
# 643:	learn: 0.2585537	total: 17.1s	remaining: 9.47s
# 644:	learn: 0.2585102	total: 17.2s	remaining: 9.44s
# 645:	learn: 0.2584576	total: 17.2s	remaining: 9.41s
# 646:	learn: 0.2584186	total: 17.2s	remaining: 9.38s
# 647:	learn: 0.2583914	total: 17.2s	remaining: 9.35s
# 648:	learn: 0.2583765	total: 17.2s	remaining: 9.32s
# 649:	learn: 0.2583482	total: 17.3s	remaining: 9.29s
# 650:	learn: 0.2583479	total: 17.3s	remaining: 9.26s
# 651:	learn: 0.2583286	total: 17.3s	remaining: 9.23s
# 652:	learn: 0.2582985	total: 17.3s	remaining: 9.2s
# 653:	learn: 0.2582966	total: 17.3s	remaining: 9.16s
# 654:	learn: 0.2582758	total: 17.3s	remaining: 9.14s
# 655:	learn: 0.2582208	total: 17.4s	remaining: 9.11s
# 656:	learn: 0.2582131	total: 17.4s	remaining: 9.08s
# 657:	learn: 0.2581777	total: 17.4s	remaining: 9.05s
# 658:	learn: 0.2581372	total: 17.4s	remaining: 9.02s
# 659:	learn: 0.2581007	total: 17.5s	remaining: 9s
# 660:	learn: 0.2580930	total: 17.5s	remaining: 8.98s
# 661:	learn: 0.2580609	total: 17.6s	remaining: 8.96s
# 662:	learn: 0.2580079	total: 17.6s	remaining: 8.95s
# 663:	learn: 0.2579461	total: 17.7s	remaining: 8.94s
# 664:	learn: 0.2579079	total: 17.7s	remaining: 8.91s
# 665:	learn: 0.2578783	total: 17.7s	remaining: 8.9s
# 666:	learn: 0.2578563	total: 17.8s	remaining: 8.89s
# 667:	learn: 0.2578346	total: 17.9s	remaining: 8.87s
# 668:	learn: 0.2578106	total: 17.9s	remaining: 8.86s
# 669:	learn: 0.2577533	total: 17.9s	remaining: 8.83s
# 670:	learn: 0.2577174	total: 18s	remaining: 8.8s
# 671:	learn: 0.2576843	total: 18s	remaining: 8.77s
# 672:	learn: 0.2576413	total: 18s	remaining: 8.75s
# 673:	learn: 0.2576043	total: 18.1s	remaining: 8.73s
# 674:	learn: 0.2575556	total: 18.1s	remaining: 8.72s
# 675:	learn: 0.2575196	total: 18.2s	remaining: 8.71s
# 676:	learn: 0.2574782	total: 18.2s	remaining: 8.7s
# 677:	learn: 0.2574242	total: 18.3s	remaining: 8.68s
# 678:	learn: 0.2573784	total: 18.3s	remaining: 8.67s
# 679:	learn: 0.2573517	total: 18.4s	remaining: 8.65s
# 680:	learn: 0.2573149	total: 18.4s	remaining: 8.64s
# 681:	learn: 0.2572874	total: 18.5s	remaining: 8.62s
# 682:	learn: 0.2572605	total: 18.5s	remaining: 8.6s
# 683:	learn: 0.2572247	total: 18.6s	remaining: 8.58s
# 684:	learn: 0.2572030	total: 18.6s	remaining: 8.56s
# 685:	learn: 0.2571693	total: 18.7s	remaining: 8.55s
# 686:	learn: 0.2571231	total: 18.7s	remaining: 8.54s
# 687:	learn: 0.2570992	total: 18.8s	remaining: 8.52s
# 688:	learn: 0.2570691	total: 18.8s	remaining: 8.5s
# 689:	learn: 0.2570359	total: 18.9s	remaining: 8.48s
# 690:	learn: 0.2570263	total: 18.9s	remaining: 8.46s
# 691:	learn: 0.2569898	total: 19s	remaining: 8.44s
# 692:	learn: 0.2569385	total: 19s	remaining: 8.43s
# 693:	learn: 0.2569048	total: 19.1s	remaining: 8.41s
# 694:	learn: 0.2569039	total: 19.1s	remaining: 8.39s
# 695:	learn: 0.2568841	total: 19.2s	remaining: 8.38s
# 696:	learn: 0.2568407	total: 19.3s	remaining: 8.37s
# 697:	learn: 0.2568040	total: 19.3s	remaining: 8.36s
# 698:	learn: 0.2567775	total: 19.4s	remaining: 8.34s
# 699:	learn: 0.2567392	total: 19.4s	remaining: 8.33s
# 700:	learn: 0.2567181	total: 19.5s	remaining: 8.31s
# 701:	learn: 0.2567175	total: 19.5s	remaining: 8.29s
# 702:	learn: 0.2567024	total: 19.6s	remaining: 8.27s
# 703:	learn: 0.2566954	total: 19.6s	remaining: 8.26s
# 704:	learn: 0.2566586	total: 19.7s	remaining: 8.24s
# 705:	learn: 0.2566230	total: 19.8s	remaining: 8.23s
# 706:	learn: 0.2565731	total: 19.8s	remaining: 8.22s
# 707:	learn: 0.2565357	total: 19.9s	remaining: 8.2s
# 708:	learn: 0.2565034	total: 19.9s	remaining: 8.18s
# 709:	learn: 0.2564747	total: 20s	remaining: 8.16s
# 710:	learn: 0.2564503	total: 20s	remaining: 8.14s
# 711:	learn: 0.2564003	total: 20.1s	remaining: 8.12s
# 712:	learn: 0.2563648	total: 20.1s	remaining: 8.1s
# 713:	learn: 0.2563310	total: 20.2s	remaining: 8.09s
# 714:	learn: 0.2562882	total: 20.2s	remaining: 8.07s
# 715:	learn: 0.2562634	total: 20.3s	remaining: 8.05s
# 716:	learn: 0.2562469	total: 20.4s	remaining: 8.04s
# 717:	learn: 0.2562000	total: 20.4s	remaining: 8.02s
# 718:	learn: 0.2561847	total: 20.5s	remaining: 8.01s
# 719:	learn: 0.2561625	total: 20.5s	remaining: 7.99s
# 720:	learn: 0.2561091	total: 20.6s	remaining: 7.97s
# 721:	learn: 0.2560905	total: 20.6s	remaining: 7.95s
# 722:	learn: 0.2560376	total: 20.7s	remaining: 7.94s
# 723:	learn: 0.2559896	total: 20.8s	remaining: 7.92s
# 724:	learn: 0.2559708	total: 20.8s	remaining: 7.91s
# 725:	learn: 0.2559401	total: 20.9s	remaining: 7.88s
# 726:	learn: 0.2558991	total: 21s	remaining: 7.87s
# 727:	learn: 0.2558661	total: 21s	remaining: 7.85s
# 728:	learn: 0.2558243	total: 21.1s	remaining: 7.83s
# 729:	learn: 0.2557845	total: 21.1s	remaining: 7.81s
# 730:	learn: 0.2557549	total: 21.2s	remaining: 7.79s
# 731:	learn: 0.2557154	total: 21.2s	remaining: 7.77s
# 732:	learn: 0.2556963	total: 21.3s	remaining: 7.74s
# 733:	learn: 0.2556506	total: 21.3s	remaining: 7.72s
# 734:	learn: 0.2555899	total: 21.4s	remaining: 7.7s
# 782:	learn: 0.2541152	total: 23.7s	remaining: 6.57s
# 783:	learn: 0.2540831	total: 23.8s	remaining: 6.55s
# 784:	learn: 0.2540385	total: 23.8s	remaining: 6.52s
# 785:	learn: 0.2540109	total: 23.9s	remaining: 6.5s
# 786:	learn: 0.2539804	total: 23.9s	remaining: 6.47s
# 787:	learn: 0.2539602	total: 24s	remaining: 6.46s
# 788:	learn: 0.2539435	total: 24.1s	remaining: 6.43s
# 789:	learn: 0.2539125	total: 24.1s	remaining: 6.41s
# 790:	learn: 0.2538684	total: 24.2s	remaining: 6.38s
# 791:	learn: 0.2538310	total: 24.2s	remaining: 6.36s
# 792:	learn: 0.2538259	total: 24.3s	remaining: 6.33s
# 793:	learn: 0.2537941	total: 24.3s	remaining: 6.31s
# 794:	learn: 0.2537773	total: 24.4s	remaining: 6.28s
# 795:	learn: 0.2537403	total: 24.4s	remaining: 6.26s
# 796:	learn: 0.2536899	total: 24.5s	remaining: 6.23s
# 797:	learn: 0.2536314	total: 24.5s	remaining: 6.21s
# 798:	learn: 0.2535842	total: 24.6s	remaining: 6.18s
# 799:	learn: 0.2535364	total: 24.6s	remaining: 6.16s
# 800:	learn: 0.2535060	total: 24.7s	remaining: 6.13s
# 801:	learn: 0.2534724	total: 24.7s	remaining: 6.11s
# 802:	learn: 0.2534419	total: 24.8s	remaining: 6.08s
# 803:	learn: 0.2534415	total: 24.8s	remaining: 6.04s
# 804:	learn: 0.2534018	total: 24.8s	remaining: 6.01s
# 805:	learn: 0.2533689	total: 24.8s	remaining: 5.98s
# 806:	learn: 0.2533316	total: 24.9s	remaining: 5.95s
# 807:	learn: 0.2532980	total: 24.9s	remaining: 5.91s
# 808:	learn: 0.2532742	total: 24.9s	remaining: 5.88s
# 809:	learn: 0.2532583	total: 24.9s	remaining: 5.84s
# 810:	learn: 0.2532291	total: 24.9s	remaining: 5.81s
# 811:	learn: 0.2531941	total: 25s	remaining: 5.78s
# 812:	learn: 0.2531612	total: 25s	remaining: 5.75s
# 813:	learn: 0.2531268	total: 25s	remaining: 5.72s
# 814:	learn: 0.2530933	total: 25s	remaining: 5.68s
# 815:	learn: 0.2530801	total: 25.1s	remaining: 5.65s
# 816:	learn: 0.2530433	total: 25.1s	remaining: 5.62s
# 817:	learn: 0.2530133	total: 25.1s	remaining: 5.59s
# 818:	learn: 0.2529830	total: 25.1s	remaining: 5.55s
# 819:	learn: 0.2529830	total: 25.1s	remaining: 5.52s
# 820:	learn: 0.2529577	total: 25.2s	remaining: 5.49s
# 821:	learn: 0.2529361	total: 25.2s	remaining: 5.45s
# 822:	learn: 0.2529135	total: 25.2s	remaining: 5.42s
# 823:	learn: 0.2528927	total: 25.2s	remaining: 5.39s
# 824:	learn: 0.2528467	total: 25.2s	remaining: 5.35s
# 825:	learn: 0.2528279	total: 25.3s	remaining: 5.32s
# 826:	learn: 0.2527931	total: 25.3s	remaining: 5.29s
# 827:	learn: 0.2527536	total: 25.3s	remaining: 5.25s
# 828:	learn: 0.2527067	total: 25.3s	remaining: 5.22s
# 829:	learn: 0.2526746	total: 25.3s	remaining: 5.19s
# 877:	learn: 0.2514767	total: 26.3s	remaining: 3.65s
# 878:	learn: 0.2514565	total: 26.3s	remaining: 3.62s
# 879:	learn: 0.2514274	total: 26.3s	remaining: 3.59s
# 880:	learn: 0.2513911	total: 26.3s	remaining: 3.56s
# 881:	learn: 0.2513705	total: 26.4s	remaining: 3.53s
# 882:	learn: 0.2513441	total: 26.4s	remaining: 3.5s
# 883:	learn: 0.2513203	total: 26.4s	remaining: 3.46s
# 884:	learn: 0.2513035	total: 26.4s	remaining: 3.43s
# 885:	learn: 0.2512883	total: 26.4s	remaining: 3.4s
# 886:	learn: 0.2512760	total: 26.5s	remaining: 3.37s
# 887:	learn: 0.2512440	total: 26.5s	remaining: 3.34s
# 888:	learn: 0.2512152	total: 26.5s	remaining: 3.31s
# 889:	learn: 0.2511751	total: 26.5s	remaining: 3.28s
# 890:	learn: 0.2511434	total: 26.5s	remaining: 3.25s
# 891:	learn: 0.2511316	total: 26.6s	remaining: 3.21s
# 892:	learn: 0.2511313	total: 26.6s	remaining: 3.18s
# 893:	learn: 0.2510942	total: 26.6s	remaining: 3.15s
# 894:	learn: 0.2510590	total: 26.6s	remaining: 3.12s
# 895:	learn: 0.2510552	total: 26.6s	remaining: 3.09s
# 896:	learn: 0.2510234	total: 26.6s	remaining: 3.06s
# 897:	learn: 0.2510055	total: 26.7s	remaining: 3.03s
# 898:	learn: 0.2509579	total: 26.7s	remaining: 3s
# 899:	learn: 0.2509276	total: 26.7s	remaining: 2.97s
# 900:	learn: 0.2508969	total: 26.7s	remaining: 2.94s
# 901:	learn: 0.2508591	total: 26.7s	remaining: 2.9s
# 902:	learn: 0.2508442	total: 26.8s	remaining: 2.88s
# 903:	learn: 0.2508090	total: 26.8s	remaining: 2.84s
# 904:	learn: 0.2507703	total: 26.8s	remaining: 2.81s
# 905:	learn: 0.2507561	total: 26.8s	remaining: 2.78s
# 906:	learn: 0.2507308	total: 26.8s	remaining: 2.75s
# 907:	learn: 0.2507006	total: 26.9s	remaining: 2.72s
# 908:	learn: 0.2506798	total: 26.9s	remaining: 2.69s
# 909:	learn: 0.2506399	total: 26.9s	remaining: 2.66s
# 910:	learn: 0.2505987	total: 27s	remaining: 2.63s
# 911:	learn: 0.2505811	total: 27s	remaining: 2.6s
# 912:	learn: 0.2505706	total: 27s	remaining: 2.57s
# 913:	learn: 0.2505699	total: 27s	remaining: 2.54s
# 914:	learn: 0.2505325	total: 27s	remaining: 2.51s
# 915:	learn: 0.2504938	total: 27.1s	remaining: 2.48s
# 916:	learn: 0.2504663	total: 27.1s	remaining: 2.45s
# 917:	learn: 0.2504354	total: 27.1s	remaining: 2.42s
# 918:	learn: 0.2504150	total: 27.1s	remaining: 2.39s
# 919:	learn: 0.2503897	total: 27.1s	remaining: 2.36s
# 920:	learn: 0.2503751	total: 27.2s	remaining: 2.33s
# 921:	learn: 0.2503437	total: 27.2s	remaining: 2.3s
# 922:	learn: 0.2503017	total: 27.2s	remaining: 2.27s
# 923:	learn: 0.2502730	total: 27.2s	remaining: 2.24s
# 924:	learn: 0.2502545	total: 27.2s	remaining: 2.21s
# 972:	learn: 0.2490258	total: 28.2s	remaining: 782ms
# 973:	learn: 0.2489814	total: 28.2s	remaining: 753ms
# 974:	learn: 0.2489448	total: 28.2s	remaining: 724ms
# 975:	learn: 0.2489044	total: 28.3s	remaining: 695ms
# 976:	learn: 0.2488796	total: 28.3s	remaining: 666ms
# 977:	learn: 0.2488537	total: 28.3s	remaining: 636ms
# 978:	learn: 0.2488314	total: 28.3s	remaining: 607ms
# 979:	learn: 0.2487914	total: 28.3s	remaining: 578ms
# 980:	learn: 0.2487471	total: 28.4s	remaining: 549ms
# 981:	learn: 0.2487223	total: 28.4s	remaining: 520ms
# 982:	learn: 0.2487009	total: 28.4s	remaining: 491ms
# 983:	learn: 0.2486849	total: 28.4s	remaining: 462ms
# 984:	learn: 0.2486561	total: 28.4s	remaining: 433ms
# 985:	learn: 0.2486274	total: 28.5s	remaining: 404ms
# 986:	learn: 0.2485813	total: 28.5s	remaining: 375ms
# 987:	learn: 0.2485348	total: 28.5s	remaining: 346ms
# 988:	learn: 0.2484960	total: 28.5s	remaining: 317ms
# 989:	learn: 0.2484680	total: 28.5s	remaining: 288ms
# 990:	learn: 0.2484406	total: 28.6s	remaining: 259ms
# 991:	learn: 0.2484133	total: 28.6s	remaining: 230ms
# 992:	learn: 0.2483768	total: 28.6s	remaining: 202ms
# 993:	learn: 0.2483534	total: 28.6s	remaining: 173ms
# 994:	learn: 0.2483436	total: 28.6s	remaining: 144ms
# 995:	learn: 0.2483149	total: 28.6s	remaining: 115ms
# 996:	learn: 0.2483040	total: 28.7s	remaining: 86.2ms
# 997:	learn: 0.2482816	total: 28.7s	remaining: 57.5ms
# 998:	learn: 0.2482625	total: 28.7s	remaining: 28.7ms
# 999:	learn: 0.2482265	total: 28.7s	remaining: 0us
# Accuracy: 0.8877535458288852
# Precision: 0.650994575045208
# Recall: 0.15157894736842106
# F1 Score: 0.24590163934426232
# Confusion Matrix:
# [[17103   193]
#  [ 2015   360]]

# %%
# Extract feature importances
feature_importances = results_catboost.get('model').get_feature_importance()
feature_names = X_train.columns

# Sort the feature importances in descending order and get the indices
indices = np.argsort(feature_importances)[::-1]

# Limit to top 25 features
top_indices = indices[:25]

# Create a figure to plot
plt.figure(figsize=(10, 8))
plt.title('Top 25 Feature Importances by CatBoost')
plt.barh(range(len(top_indices)), feature_importances[top_indices], color='b', align='center')
plt.yticks(range(len(top_indices)), [feature_names[i] for i in top_indices])
plt.gca().invert_yaxis()  # Invert the y-axis to have the most important at the top
plt.xlabel('Relative Importance')
plt.show()

# %%
from scipy.stats import chi2_contingency

# Assuming 'B' and 'C' are categorical and converted to type 'category'
pandas_df['CIUDAD'] = pandas_df['CIUDAD'].astype('category')
pandas_df['MaxCategoriaVehiculo'] = pandas_df['MaxCategoriaVehiculo'].astype('category')

# Create a contingency table
contingency_table = pd.crosstab(pandas_df['CIUDAD'], pandas_df['MaxCategoriaVehiculo'])

# Perform Chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)
print("Chi-square test p-value:", p)
# Out:
# Chi-square test p-value: 0.0

# %%
new_session.close()
