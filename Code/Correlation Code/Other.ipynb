# %% [markdown]
# Ordering the df (not yet useful for limited data)

# %%
# df_sample = session.sql("SELECT * FROM CONSOLIDATED_COPY LIMIT 10")
# print(df_sample.collect())

# %%
df_v=session.sql('select * from CONSOLIDATED_COPY ')
df_v = df_v.select([F.col(col_name).alias(col_name.replace('"', '')) for col_name in df_v.columns])
df_v= df_v.sort(col("FECHAEMISION"))
